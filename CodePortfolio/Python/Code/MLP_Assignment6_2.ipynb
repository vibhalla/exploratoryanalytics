# %%
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

iris_raw = pd.read_csv('iris.csv')
c = iris_raw.iloc[:,0:4]
top_features = 2
pca = PCA(n_components=top_features)
best_fit_iris_data = pca.fit_transform(iris_data)
print("Top ",top_features,"components by variation :", pca.explained_variance_ratio_) 

iris_new = pca.inverse_transform(best_fit_iris_data)
plt.scatter(iris_raw.iloc[:, 0], iris_raw.iloc[:, 1],marker='s')
plt.scatter(iris_new[:, 0], iris_new[:, 1], marker='*')
plt.title("Blue Square - Orginal data, Orange Stars - Compact data")
plt.show()
# Out:
# Top  2 components by variation : [0.92384162 0.05590108]
